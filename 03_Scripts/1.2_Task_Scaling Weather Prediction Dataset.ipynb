# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 02. Import Data

# %%
path = r'C:\Users\esteb\OneDrive\Desktop\2025_Machine Learning'

# %%
df = pd.read_csv(os.path.join(path, '02_Data', 'Original Data', 'Weather-prediction-dataset-processed.csv'))

# %% [markdown]
# # 03. Data Summary

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
# Min and max dates
min_date = df['DATE'].min()
max_date = df['DATE'].max()

print("Min date:", min_date)
print("Max date:", max_date)
# Out:
# Min date: 19600101
# Max date: 20221031

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %%
pd.set_option('display.max_info_columns', 200)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Data columns (total 171 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    id                           22950 non-null  int64
#  1    DATE                         22950 non-null  int64
#  2    MONTH                        22950 non-null  int64
#  3    BASEL_cloud_cover            22950 non-null  int64
#  4    BASEL_wind_speed             22950 non-null  float64
#  5    BASEL_humidity               22950 non-null  float64
#  6    BASEL_pressure               22950 non-null  float64
#  7    BASEL_global_radiation       22950 non-null  float64
#  8    BASEL_precipitation          22950 non-null  float64
#  9    BASEL_snow_depth             22950 non-null  int64
#  10   BASEL_sunshine               22950 non-null  float64
#  11   BASEL_temp_mean              22950 non-null  float64
# ...

# %%
pd.reset_option('display.max_info_columns')

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
#Eliminate potential records that have NaN values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (22950, 171)

# %% [markdown]
# # 04. Scaling

# %%
# Create scaler object using StandardScaler from sklearn.preprocessing
# StandardScaler assumes data is normally distributed and scales with a distribution
# Around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
# Create new df with scaled data

df_scaled = pd.DataFrame(scaler.fit_transform(df))
df_scaled.head()
# Out:
#         0         1         2         3        4         5         6    \
# 0 -1.731975 -1.707663 -1.599964  0.660514 -0.02793  0.826097 -0.001949
# 1 -1.731824 -1.707657 -1.599964  0.244897 -0.02793  0.735760 -0.001949
# 2 -1.731673 -1.707652 -1.599964  1.076130 -0.02793  1.277781 -0.001949
# 3 -1.731523 -1.707646 -1.599964 -1.001953 -0.02793  1.458455 -0.001949
# 4 -1.731372 -1.707641 -1.599964  0.244897 -0.02793  1.729466 -0.001949
#
#         7         8         9    ...       161       162       163       164  \
# 0 -1.101066 -0.265148 -0.179228  ... -0.443701  0.761754 -1.299744 -0.806427
# 1 -1.058108  1.658760 -0.179228  ...  0.783085  1.183580 -1.262455 -1.042055
# 2 -1.251420  0.155707 -0.179228  ...  0.783085  1.183580 -0.432779 -1.136306
# 3 -0.821838 -0.445514 -0.179228  ...  0.783085  0.480538  0.387574 -1.183432
# 4 -0.746661 -0.164944 -0.179228  ... -1.670486 -0.363113  1.729970 -0.794645
#
#         165       166       167       168       169       170
# ...

# %%
# Compare df vs df_scaled
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %% [markdown]
# # 05. Export

# %%
# Export df 
df_scaled.to_pickle(os.path.join(path,'02_Data', 'Prepared Data', 'Weather-prediction-dataset-scaled.pkl'))

# %%
# Export df 
df_scaled.to_csv(os.path.join(path,'02_Data', 'Prepared Data', 'Weather-prediction-dataset-scaled.csv'))
